# %% [markdown]
# <a href="https://colab.research.google.com/github/mariabykova-git/Python-/blob/main/Python_%D0%B4%D0%BB%D1%8F_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85__%D0%98%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D1%8B%D0%B8__%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82_%D0%91%D1%8B%D0%BA%D0%BE%D0%B2%D0%B0%D0%9C%D0%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
data = pd.read_csv('dst-3.0_16_1_hh_database.csv', sep=';')
data.shape
# Out:
# (44744, 12)

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
display(data)
# Out:
#                                        Пол, возраст           ЗП  \
# 0        Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1         Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2      Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3          Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4         Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
# ...                                             ...          ...
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#                                Ищет работу на должность:  \
# 0                                Системный администратор
# 1                                   Технический писатель
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
def extract_education_level(text):
    if pd.isna(text):
        return 'не указано'

    words = text.split()
    # Берем первые 2-3 слова (максимальный уровень образования)
    education_part = ' '.join(words[:3]).lower()

    if 'высшее образование' in education_part:
        return 'высшее'
    elif 'неоконченное высшее' in education_part:
        return 'неоконченное высшее'
    elif 'среднее специальное' in education_part:
        return 'среднее специальное'
    elif 'среднее ' in education_part:
        return 'среднее'
    else:
        return 'не указано'

# Создаем новый признак "Образование"
data['Образование'] = data['Образование и ВУЗ'].apply(extract_education_level)

# Проверяем уникальные категории
print(data['Образование'].unique())
print()
print(data['Образование'].value_counts())
# Out:
# ['высшее' 'среднее специальное' 'среднее']
#
# Образование
# высшее                 38420
# среднее специальное     5765
# среднее                  559
# Name: count, dtype: int64

# %%
# Удаляем старый столбец
data.drop('Образование и ВУЗ', axis=1, inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Обновление резюме                44744 non-null  object
#  10  Авто                             44744 non-null  object
#  11  Образование                      44744 non-null  object
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
def extract_gender_age(text):
    if pd.isna(text):
        return 'не указано', 0

    parts = text.split(' , ')
    gender_full = parts[0].strip()
    age_part = parts[1].strip()

    # Извлекаем пол
    if 'Мужчина' in gender_full:
        gender = 'М'
    elif 'Женщина' in gender_full:
        gender = 'Ж'
    else:
        gender = 'не указано'

    # Извлекаем возраст (число до "лет" или "год")
    age_text = age_part.split()[0]
    age = int(age_text)

    return gender, age

# Создаем новые признаки
data[['Пол', 'Возраст']] = data['Пол, возраст'].apply(
    lambda x: pd.Series(extract_gender_age(x))
)

# Проверяем уникальные значения
print(data['Пол'].unique())
print()
print(sorted(data['Возраст'].unique())[:10])
print()
print(data['Пол'].value_counts())
# Out:
# ['М' 'Ж']
#
# [np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23)]
#
# Пол
# М    36211
# Ж     8533
# Name: count, dtype: int64

# %%
# Процент женских резюме
women_percent = round((data['Пол'] == 'Ж').mean() * 100, 2)
print(f"Ж: {women_percent}%")

# Средний возраст
avg_age = round(data['Возраст'].mean(), 1)
print(f"Возраст: {avg_age}")
# Out:
# Ж: 19.07%
# Возраст: 32.2

# %%
# Удаляем старый столбец
data.drop('Пол, возраст', axis=1, inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Город, переезд, командировки     44744 non-null  object
#  3   Занятость                        44744 non-null  object
#  4   График                           44744 non-null  object
#  5   Опыт работы                      44576 non-null  object
#  6   Последнее/нынешнее место работы  44743 non-null  object
#  7   Последняя/нынешняя должность     44742 non-null  object
#  8   Обновление резюме                44744 non-null  object
#  9   Авто                             44744 non-null  object
#  10  Образование                      44744 non-null  object
#  11  Пол                              44744 non-null  object
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
import re

def extract_work_experience(text):
    if pd.isna(text) or text == 'Не указано':
        return np.nan

    # Ищем паттерн "Опыт работы X года Y месяца" или только года/месяца
    pattern = r'Опыт работы\s+(\d+)\s*(?:года?|лет)\s*(?:(\d+)\s*(?:месяца?|мес))?'
    match = re.search(pattern, str(text))

    if not match:
        return np.nan

    years = int(match.group(1)) if match.group(1) else 0
    months = int(match.group(2)) if match.group(2) else 0

    total_months = years * 12 + months
    return total_months

# Создаем новый признак "Опыт работы (месяц)"
data['Опыт работы (месяц)'] = data['Опыт работы'].apply(extract_work_experience)

# Медианный опыт работы
median_experience = data['Опыт работы (месяц)'].median()
print(median_experience)
# Out:
# 103.0

# %%
# Удаляем старый столбец
data.drop('Опыт работы', axis=1, inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Город, переезд, командировки     44744 non-null  object
#  3   Занятость                        44744 non-null  object
#  4   График                           44744 non-null  object
#  5   Последнее/нынешнее место работы  44743 non-null  object
#  6   Последняя/нынешняя должность     44742 non-null  object
#  7   Обновление резюме                44744 non-null  object
#  8   Авто                             44744 non-null  object
#  9   Образование                      44744 non-null  object
#  10  Пол                              44744 non-null  object
#  11  Возраст                          44744 non-null  int64
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
# Список городов-миллионников
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]

def extract_city_relocation_trips(text):
    if pd.isna(text):
        return 'другие', False, False

    parts = text.split(' , ')

    # Город - первая часть
    city_part = parts[0].strip()
    city = city_part.split(',')[0].strip()  # Убираем метро

    # Категоризация города
    if city == 'Москва':
        city_category = 'Москва'
    elif city == 'Санкт-Петербург':
        city_category = 'Санкт-Петербург'
    elif city in million_cities:
        city_category = 'город-миллионник'
    else:
        city_category = 'другие'

    # Готовность к переезду
    relocation = False
    for part in parts:
        part_lower = part.lower()
        if any(phrase in part_lower for phrase in ['готов к переезду', 'готова к переезду', 'хочу переехать', 'готов переехать']):
            relocation = True
            break

    # Готовность к командировкам
    trips = False
    for part in parts:
        part_lower = part.lower()
        if any(phrase in part_lower for phrase in ['готов к командировкам', 'готова к командировкам']):
            trips = True
            break

    return city_category, relocation, trips

# Создаем новые признаки
data[['Город', 'Готовность к переезду', 'Готовность к командировкам']] = data['Город, переезд, командировки'].apply(
    lambda x: pd.Series(extract_city_relocation_trips(x))
)

# Процент соискателей из Санкт-Петербурга
spb_percent = round((data['Город'] == 'Санкт-Петербург').mean() * 100)
print(f"{spb_percent}%")

# Процент соискателей готовых и к переезду, и к командировкам
both_ready_percent = round(data[(data['Готовность к переезду'] == True) & (data['Готовность к командировкам'] == True)].shape[0] / len(data) * 100)
print(f"{both_ready_percent}%")
# Out:
# 11%
# 76%

# %%
# Удаляем старый столбец
data.drop('Город, переезд, командировки', axis=1, inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Занятость                        44744 non-null  object
#  3   График                           44744 non-null  object
#  4   Последнее/нынешнее место работы  44743 non-null  object
#  5   Последняя/нынешняя должность     44742 non-null  object
#  6   Обновление резюме                44744 non-null  object
#  7   Авто                             44744 non-null  object
#  8   Образование                      44744 non-null  object
#  9   Пол                              44744 non-null  object
#  10  Возраст                          44744 non-null  int64
#  11  Опыт работы (месяц)              43090 non-null  float64
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# One-Hot Encoding для "Занятость"
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
for category in employment_categories:
    data[f'Занятость_{category}'] = data['Занятость'].str.contains(category, na=False)

# One-Hot Encoding для "График"
schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']
for category in schedule_categories:
    data[f'График_{category}'] = data['График'].str.contains(category, na=False)

# Проектная работа и волонтерство
project_volunteer = data[(data['Занятость_проектная работа'] == True) & (data['Занятость_волонтерство'] == True)].shape[0]
print(f"{project_volunteer}")

# Вахтовый метод и гибкий график
flexible_shift = data[(data['График_вахтовый метод'] == True) & (data['График_гибкий график'] == True)].shape[0]
print(f"{flexible_shift}")
# Out:
# 436
# 2311

# %%
# Удаляем исходные столбцы
data.drop(['Занятость', 'График'], axis=1, inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Последнее/нынешнее место работы  44743 non-null  object
#  3   Последняя/нынешняя должность     44742 non-null  object
#  4   Обновление резюме                44744 non-null  object
#  5   Авто                             44744 non-null  object
#  6   Образование                      44744 non-null  object
#  7   Пол                              44744 non-null  object
#  8   Возраст                          44744 non-null  int64
#  9   Опыт работы (месяц)              43090 non-null  float64
#  10  Город                            44744 non-null  object
#  11  Готовность к переезду            44744 non-null  bool
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
def get_salary_num(arg):
    salary =float(arg.split(' ')[0])
    return salary
# Словарь валют
def get_salary_currency(arg):
    currency_dict = {
        'USD': 'USD', 'KZT': 'KZT',
        'грн': 'UAH', 'белруб': 'BYN',
        'EUR': 'EUR', 'KGS': 'KGS',
        'сум': 'UZS', 'AZN': 'AZN'
    }
    curr = arg.split(' ')[1].replace('.', '')
    if curr == 'руб':
        return 'RUB'
    else:
        return currency_dict[curr]

# Загружаем файл с курсом валют
rates = pd.read_csv('ExchangeRates.csv')
rates['date'] = pd.to_datetime(rates['date'], dayfirst=True).dt.date

data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме'], dayfirst=True).dt.date
data['ЗП (tmp)'] = data['ЗП'].apply(get_salary_num)
data['Курс (tmp)'] = data['ЗП'].apply(get_salary_currency)
merged = data.merge(
    rates,
    left_on=['Курс (tmp)', 'Обновление резюме'],
    right_on=['currency', 'date',],
    how='left'
)
merged['close'] = merged['close'].fillna(1)
merged['proportion'] = merged['proportion'].fillna(1)
data['ЗП (руб)'] = merged['close'] * merged['ЗП (tmp)'] / merged['proportion']
data = data.drop(['ЗП', 'ЗП (tmp)', 'Курс (tmp)'], axis=1)
print(round(data['ЗП (руб)'].median()/1000))
# Out:
# /tmp/ipython-input-3929023214.py:20: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   rates['date'] = pd.to_datetime(rates['date'], dayfirst=True).dt.date
# 59

# %%
# Удаляем исходные столбцы
columns_to_drop = ['ЗП', 'ЗП_сумма', 'ЗП_валюта', 'currency', 'date', 'proportion', 'close']
data.drop(columns_to_drop, axis=1, errors='ignore', inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  object
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              43090 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
#  11  Готовность к командировкам       44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Гистограмма
data['Возраст'].hist(bins=30, ax=axes[0], edgecolor='black')
axes[0].set_title('Распределение возраста (гистограмма)')
axes[0].set_xlabel('Возраст')
axes[0].set_ylabel('Частота')

# Коробчатая диаграмма
sns.boxplot(y=data['Возраст'], ax=axes[1])
axes[1].set_title('Распределение возраста (boxplot)')

plt.tight_layout()
plt.show()

# Статистики
print("Мода:", data['Возраст'].mode()[0])
print("Минимум:", data['Возраст'].min())
print("Максимум:", data['Возраст'].max())
print("Медиана:", data['Возраст'].median())
print("25-75% интервал:", data['Возраст'].quantile([0.25, 0.75]).values)
# Out:
# Мода: 30
# Минимум: 14
# Максимум: 100
# Медиана: 31.0
# 25-75% интервал: [27. 36.]

# %% [markdown]
# Наиболее частый возраст соискателей — 30 лет.
# Возраст варьируется от 14 до 100 лет.
# Большинство соискателей в возрасте 27-36 лет.
#
# Предельные значения: меньше 20 лет — школьники, которые маловероятно ищут полную занятость; больше 60 лет — пенсионный возраст, редко активны на рынке труда
#
# Распределение правостороннее (длинный хвост вправо), типично для трудоспособного взрослого населения.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Гистограмма опыта работы
data['Опыт работы (месяц)'].hist(bins=50, ax=axes[0], edgecolor='black')
axes[0].set_title('Распределение опыта работы (гистограмма)')
axes[0].set_xlabel('Опыт работы (месяцы)')
axes[0].set_ylabel('Частота')

# Коробчатая диаграмма
sns.boxplot(y=data['Опыт работы (месяц)'], ax=axes[1])
axes[1].set_title('Распределение опыта работы (boxplot)')

plt.tight_layout()
plt.show()

# Статистики
print("Мода:", data['Опыт работы (месяц)'].mode()[0])
print("Минимум:", data['Опыт работы (месяц)'].min())
print("Максимум:", data['Опыт работы (месяц)'].max())
print("Медиана:", data['Опыт работы (месяц)'].median())
print("25-75% интервал:", data['Опыт работы (месяц)'].quantile([0.25, 0.75]).values)
print("Пропуски:", data['Опыт работы (месяц)'].isna().sum())
# Out:
# Мода: 81.0
# Минимум: 12.0
# Максимум: 1188.0
# Медиана: 103.0
# 25-75% интервал: [ 61. 157.]
# Пропуски: 1654

# %% [markdown]
# Наиболее частый опыт — 81 месяцев (мода).
#
# Мининум 12 месяцев и максимум 1188 месяцев (99 лет опыта - выпад).
#
# Большинство соискателей имеют 61-157 месяцев опыта.
#
# Распределение сильно правостороннее с длинным хвостом, что говорит об опытных кадрах.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Гистограмма ЗП
salary_data = data['ЗП (руб)'].dropna()
log_salary = np.log10(salary_data)  # Логарифмируем для лучшей видимости
axes[0].hist(log_salary, bins=50, edgecolor='black', alpha=0.7)
axes[0].set_title('Распределение log10(ЗП) (гистограмма)')
axes[0].set_xlabel('log10(Зарплата, руб)')
axes[0].set_ylabel('Частота')
axes[0].grid(True, alpha=0.3)

# Коробчатая диаграмма
sns.boxplot(y=salary_data, ax=axes[1])
axes[1].set_title('Распределение ЗП (boxplot)')

plt.tight_layout()
plt.show()

print("Мода:", data['ЗП (руб)'].mode()[0])
print("Минимум:", data['ЗП (руб)'].min())
print("Максимум:", data['ЗП (руб)'].max())
print("Медиана:", data['ЗП (руб)'].median())
print("25-75% интервал:", data['ЗП (руб)'].quantile([0.25, 0.75]).values)
print("Пропуски:", data['ЗП (руб)'].isna().sum())
# Out:
# Мода: 50000.0
# Минимум: 1.0
# Максимум: 24304876.0
# Медиана: 59019.0
# 25-75% интервал: [37082.2 95000. ]
# Пропуски: 0

# %% [markdown]
# Средняя заработная плата - 59 019 руб. Наиболее часто встречающееся значение - 50 000 руб.
#
# Предельные знаения: мининум 1  максимум 24304876 руб. 1 - явно выпад, от таких данных необходимо очищать
#
# Распределение близко к нормальному (по гистограмме).
#
# По коробчатому графику ЗП выше 1 000 000 руб. ищет лишь один соискатель

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# Фильтруем данные: ЗП < 1 млн рублей
salary_filtered = data[data['ЗП (руб)'] < 1_000_000].dropna(subset=['ЗП (руб)'])

# Группируем по образованию и вычисляем медиану
salary_by_education = salary_filtered.groupby('Образование', observed=True)['ЗП (руб)'].median().sort_values(ascending=False)

# Строим горизонтальную столбчатую диаграмму
plt.figure(figsize=(10, 6))
salary_by_education.plot(kind='barh', color='skyblue', edgecolor='navy')
plt.title('Медианная желаемая ЗП по уровню образования (< 1 млн руб.)')
plt.xlabel('Медианная ЗП (руб)')
plt.ylabel('Уровень образования')
plt.tight_layout()
plt.show()

print("Медианная ЗП по образованию:")
print(salary_by_education.round(0).astype(int))
# Out:
# Медианная ЗП по образованию:
# Образование
# высшее                 60000
# среднее                40000
# среднее специальное    40000
# Name: ЗП (руб), dtype: int64

# %% [markdown]
# Самая высокая желанная ЗП у соискателей с высшим образованием. считаю, что уровень образования критически важен и естественно, что у соискателей с высшим образованием запрос на ЗП выше

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# Фильтруем данные: ЗП < 1 млн рублей
salary_filtered = data[data['ЗП (руб)'] < 1_000_000].dropna(subset=['ЗП (руб)'])

# Группируем по городам и строим boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=salary_filtered, x='Город', y='ЗП (руб)')
plt.title('Распределение ЗП по городам (< 1 млн руб.)')
plt.xlabel('Город')
plt.ylabel('Желаемая ЗП (руб)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Медианы по городам
median_salary_by_city = salary_filtered.groupby('Город', observed=True)['ЗП (руб)'].median().sort_values(ascending=False)
print("Медианная ЗП по городам:")
print(median_salary_by_city.round(0).astype(int))
# Out:
# Медианная ЗП по городам:
# Город
# Москва              85000
# Санкт-Петербург     60000
# город-миллионник    40000
# другие              40000
# Name: ЗП (руб), dtype: int64

# %% [markdown]
# Москва и Санкт-Петербург имеют высокую медиану + наибольший размах. В городах-миллионниках и других городах размах ниже и медианная ЗП соискатедей ниже. Поэтому признак "город" очень важен при прогнозировапнии уровня ЗП

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# Фильтруем данные (исключаем NaN и экстремальные значения)
salary_filtered = data.dropna(subset=['ЗП (руб)'])
salary_filtered = salary_filtered[salary_filtered['ЗП (руб)'] < 1_000_000]

# Многоуровневая столбчатая диаграмма
plt.figure(figsize=(12, 6))
sns.barplot(data=salary_filtered,
            x='Готовность к командировкам',
            y='ЗП (руб)',
            hue='Готовность к переезду')
plt.title('Медианная ЗП: Готовность к командировкам и переезду')
plt.ylabel('Медианная желаемая ЗП (руб)')
plt.xlabel('Готовность к командировкам')
plt.legend(title='Готовность к переезду')
plt.tight_layout()
plt.show()

# Точная таблица медиан
pivot_table = salary_filtered.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().unstack()
print("Медианная ЗП по готовности (руб):")
print(pivot_table.round(0).astype(int))
# Out:
# Медианная ЗП по готовности (руб):
# Готовность к командировкам  False  True
# Готовность к переезду
# True                        60000  55000

# %% [markdown]
# Если соискатели готовы к командировкам + переезду — они запрашивают максимальную ЗП
#
# Если не готовы ни к чему — минимальная ЗП

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# Фильтруем данные от выбросов и пропусков
salary_filtered = data.dropna(subset=['ЗП (руб)', 'Возраст', 'Образование'])
salary_filtered = salary_filtered[salary_filtered['ЗП (руб)'] < 1_000_000]

# Создаем сводную таблицу: медиана ЗП по возрасту и образованию
pivot_table = salary_filtered.groupby(['Возраст', 'Образование'], observed=True)['ЗП (руб)'].median().unstack().fillna(0)

# Строим тепловую карту
plt.figure(figsize=(14, 10))
sns.heatmap(pivot_table, annot=True, fmt='.0f', cmap='YlOrRd', cbar_kws={'label': 'Медианная ЗП (руб)'})
plt.title('Медианная ЗП: Возраст × Образование')
plt.xlabel('Уровень образования')
plt.ylabel('Возраст')
plt.tight_layout()
plt.show()

print("Сводная таблица (первые 10 строк):")
print(pivot_table.head(10).round(0).astype(int))
# Out:
# Сводная таблица (первые 10 строк):
# Образование  высшее  среднее  среднее специальное
# Возраст
# 14            60000        0                    0
# 15                0    10000                 2000
# 16           122582        0                30000
# 17            80000    44000                25000
# 18            25000    35000                25151
# 19            30000    45000                30000
# 20            30000    29000                30000
# 21            35000    40000                30000
# 22            40000    40000                30000
# 23            45000    35000                35000

# %% [markdown]
# Пик зарплатных ожиданий: 30-50 лет — максимальные значения по всем уровням образования
#
# Высшее образование доминирует: ярко-красные области везде, особенно 40-50 лет
#
# Молодежь (18-25 лет): низкие ожидания, среднее образование особенно невыгодно. Вылет по ЗП в возрасте 16 лет и 69 лет
#
# После 50 лет: резкое падение ожиданий у всех категорий

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# Фильтруем данные и переводим опыт в годы
df_clean = data.dropna(subset=['Возраст', 'Опыт работы (месяц)'])
df_clean['Опыт_лет'] = df_clean['Опыт работы (месяц)'] / 12

# Диаграмма рассеяния
plt.figure(figsize=(10, 8))
plt.scatter(df_clean['Возраст'], df_clean['Опыт_лет'], alpha=0.6, s=10)
plt.plot([0, 100], [0, 100], 'r--', linewidth=2, label='Опыт = Возраст (аномалии)')

plt.xlabel('Возраст (лет)')
plt.ylabel('Опыт работы (лет)')
plt.title('Опыт работы vs Возраст')
plt.grid(True, alpha=0.3)
plt.legend()
plt.axis('equal')
plt.tight_layout()
plt.show()

# Анализ аномалий
anomalies = df_clean[df_clean['Опыт_лет'] >= df_clean['Возраст']]
print(f"Аномалий (опыт >= возраст): {len(anomalies)}")
print("Примеры аномалий:")
print(anomalies[['Возраст', 'Опыт_лет']].head())

# Считаем точки СТРОГО ВЫШЕ прямой (опыт > возраст)
anomalies_above = df_clean[df_clean['Опыт_лет'] > df_clean['Возраст']]
count_above = len(anomalies_above)

print(f"Количество точек СТРОГО ВЫШЕ прямой: {count_above}")

# Показываем примеры аномалий
print("\nПримеры аномалий (опыт > возраст):")
print(anomalies_above[['Возраст', 'Опыт работы (месяц)', 'Опыт_лет']].head())
# Out:
# /tmp/ipython-input-3502642724.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Опыт_лет'] = df_clean['Опыт работы (месяц)'] / 12
# Аномалий (опыт >= возраст): 7
# Примеры аномалий:
#        Возраст   Опыт_лет
# 4535        18  22.583333
# 19351       28  39.166667
# 19872       34  34.666667
# 26477       34  34.250000
# 29098       14  39.750000
# Количество точек СТРОГО ВЫШЕ прямой: 7
#
# Примеры аномалий (опыт > возраст):
#        Возраст  Опыт работы (месяц)   Опыт_лет
# 4535        18                271.0  22.583333
# 19351       28                470.0  39.166667
# 19872       34                416.0  34.666667
# 26477       34                411.0  34.250000
# 29098       14                477.0  39.750000

# %% [markdown]
# Основная зависимость - облако точек лежит ниже диагонали, это значит, что опыт всегда меньше возраста. Точки выше прямой - опыт больше возраста - аномальные значения, должны быть удалены

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# 1. Корреляционная матрица числовых признаков
# Выбираем числовые признаки, созданные ранее
numeric_features = ['Возраст', 'Опыт работы (месяц)', 'ЗП (руб)']

# Корреляционная матрица
plt.figure(figsize=(8, 6))
correlation_matrix = data[numeric_features].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0,
            square=True, fmt='.3f')
plt.title('Корреляция числовых признаков')
plt.tight_layout()
plt.show()

# %% [markdown]
# Выводы:
#
# Сильная корреляция Возраст-Опыт 0.831
#
# Слабая корреляция Опыт-ЗП 0.12, Возраст-ЗП 0.098 — возраст и опыт мало влияет

# %%
# 2. Violin plot для опыта работы по уровням образования
plt.figure(figsize=(12, 6))
sns.violinplot(data=data, x='Образование', y='Опыт работы (месяц)')
plt.title('Распределение опыта работы по образованию (Violin Plot)')
plt.xticks(rotation=45)
plt.ylabel('Опыт работы (месяцы)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Высшее образование: самый широкий диапазон опыта
#
# Среднее: смещено к низкому опыту
#
# Среднее специальное: стабильный средний опыт
#
# Высшее образование коррелирует с долгосрочной карьерой, среднее — с началом карьеры.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# Поиск полных дубликатов
duplicates_count = data.duplicated().sum()
print(duplicates_count)

# Удаление дубликатов (оставляем первое вхождение)
data = data.drop_duplicates()
print(f"Размер таблицы после удаления дубликатов: {data.shape}")
# Out:
# 161
# Размер таблицы после удаления дубликатов: (44583, 23)

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Информация о пропусках в очищенных данных
missing_data = data.isnull().sum()
missing_percent = (data.isnull().sum() / len(data)) * 100

# Создаем таблицу пропусков
missing_table = pd.DataFrame({
    'Пропуски': missing_data,
}).sort_values('Пропуски', ascending=False)

print(missing_table[missing_table['Пропуски'] > 0])
# Out:
#                                  Пропуски
# Опыт работы (месяц)                  1646
# Последняя/нынешняя должность            2
# Последнее/нынешнее место работы         1

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удаляем строки с пропусками
data = data.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

# Заполняем пропуски медианой
median_experience = data['Опыт работы (месяц)'].median()
data['Опыт работы (месяц)'] = data['Опыт работы (месяц)'].fillna(median_experience)

print(f"Размер таблицы после удаления строк: {data.shape}")
print(f"Медиана опыта работы: {median_experience:.0f} месяцев")
# Out:
# Размер таблицы после удаления строк: (44581, 23)
# Медиана опыта работы: 103 месяцев

# %%
#Проверка пропусков
print(data[['Опыт работы (месяц)', 'Последнее/нынешнее место работы', 'Последняя/нынешняя должность']].isnull().sum())
# Out:
# Опыт работы (месяц)                0
# Последнее/нынешнее место работы    0
# Последняя/нынешняя должность       0
# dtype: int64

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# Удаляем выбросы по ЗП: < 1000 руб или > 1 млн руб

data_clean = data[(data['ЗП (руб)'] >= 1000) & (data['ЗП (руб)'] <= 1_000_000)]

print(f"Удалено выбросов: {len(data) - len(data_clean)} строк")

# Обновляем основной датафрейм
data = data_clean.copy()
# Out:
# Удалено выбросов: 89 строк

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Находим резюме где опыт в годах превышает возраст
data['Опыт_лет'] = data['Опыт работы (месяц)'] / 12

anomalies = data[data['Опыт_лет'] > data['Возраст']]
print(f"Найдено резюме с опытом > возраст: {len(anomalies)}")

# Удаляем аномалии
data = data[data['Опыт_лет'] <= data['Возраст']].drop(columns=['Опыт_лет'])
# Out:
# Найдено резюме с опытом > возраст: 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# Логарифмическое преобразование возраста
data['log_age'] = np.log1p(data['Возраст'])  # log(1+x) для избежания log(0)

# Строим гистограмму в логарифмическом масштабе
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=data, x='log_age', bins=30, kde=True, ax=ax)
ax.set_title('Распределение log(Возраст) с линиями 3σ')

# Среднее и 3 сигмы
mean_log_age = data['log_age'].mean()
std_log_age = data['log_age'].std()

# Линии: среднее (черная), ±3σ (красная)
ax.axvline(mean_log_age, color='k', lw=2, label=f'Среднее: {mean_log_age:.2f}')
ax.axvline(mean_log_age + 3*std_log_age, color='r', lw=2, linestyle='--', label='3σ')
ax.axvline(mean_log_age - 3*std_log_age, color='r', lw=2, linestyle='--')

plt.legend()
plt.xlabel('log(Возраст)')
plt.ylabel('Частота')
plt.show()

print(f"Среднее log(возраст): {mean_log_age:.2f}")
print(f"Стандартное отклонение: {std_log_age:.2f}")
# Out:
# Среднее log(возраст): 3.48
# Стандартное отклонение: 0.22

# %%
# Границы выбросов: ±3σ + послабление +1σ справа = -3σ / +4σ
lower_bound = mean_log_age - 3 * std_log_age
upper_bound = mean_log_age + 4 * std_log_age  # +1σ послабление

# Находим выбросы
outliers_log = data[(data['log_age'] < lower_bound) | (data['log_age'] > upper_bound)]
outliers_age = data[np.log1p(data['Возраст']) < lower_bound]['Возраст'].tolist() + \
               data[np.log1p(data['Возраст']) > upper_bound]['Возраст'].tolist()

print(f"Выбросы найдены: {len(outliers_log)}")
print("Возраст выбросов:", sorted(set(outliers_age)))

# Удаляем выбросы
data = data[(data['log_age'] >= lower_bound) & (data['log_age'] <= upper_bound)].drop(columns=['log_age'])

print(f"Размер после удаления: {data.shape}")
# Out:
# Выбросы найдены: 3
# Возраст выбросов: [15, 100]
# Размер после удаления: (44482, 23)
